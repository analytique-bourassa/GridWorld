# %%
from grid import Grid 
from grid import Move
import numpy as np

# %matplotlib inline

# %% [markdown]
# # 1. Initial policy

# %%
gridworld = Grid()


initial_policy = np.array([[Move.RIGHT.value ,Move.RIGHT.value ,Move.RIGHT.value  ,Move.STAY.value],
                           [Move.UP.value    ,Move.STAY.value  ,Move.UP.value     ,Move.STAY.value],
                           [Move.RIGHT.value ,Move.RIGHT.value ,Move.RIGHT.value  ,Move.UP.value  ]
                          ])


gridworld.show_policy(initial_policy)
# Out:
# /home/louis/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# gridworld.show_values(np.array([[0,0,0,1],[0,0,0,-1],[0,0,0,0]]))

# %% [markdown]
# # 2. Evaluate the values function of the policy

# %%
values = gridworld.evaluate_policy_by_iteration(initial_policy)

# %%
gridworld.show_values(values)
# Out:
# /home/louis/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# # 3. Improving the policy

# %%
newPolicy,newValues = gridworld.improve_policy(initial_policy,values)

# %%
final_values_MonteCarlo = gridworld.evaluate_policy_by_MonteCarlo(newPolicy)
final_values_Iteration = gridworld.evaluate_policy_by_iteration(newPolicy)

# %% [markdown]
# # 4. Final result

# %%
gridworld.show_policy(newPolicy)
# Out:
# /home/louis/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
gridworld.show_values(final_values_MonteCarlo)
# Out:
# /home/louis/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
gridworld.show_values(final_values_Iteration)
# Out:
# /home/louis/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
